# %% [markdown]
# <a href="https://colab.research.google.com/github/AinSern/personality-prediction-using-opencv/blob/main/personality%20prediction%20opencv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Data
df = pd.read_csv("responses.csv")
df.shape
# Out:
# (1010, 150)

# %%
df = df.iloc[:, 76:133]
df.head(5)
# Out:
#    Daily events  Prioritising workload  Writing notes  Workaholism  \
# 0           2.0                    2.0            5.0          4.0
# 1           3.0                    2.0            4.0          5.0
# 2           1.0                    2.0            5.0          3.0
# 3           4.0                    4.0            4.0          5.0
# 4           3.0                    1.0            2.0          3.0
#
#    Thinking ahead  Final judgement  Reliability  Keeping promises  \
# 0             2.0              5.0          4.0               4.0
# 1             4.0              1.0          4.0               4.0
# 2             5.0              3.0          4.0               5.0
# 3             3.0              1.0          3.0               4.0
# 4             5.0              5.0          5.0               4.0
#
#    Loss of interest  Friends versus money  ...  Happiness in life  \
# 0               1.0                   3.0  ...                4.0
# ...

# %% [markdown]
# prepare the data

# %%
#Drop NAs
df = df.dropna()
#...............................................................................................
#Encode categorical data
from sklearn.preprocessing import LabelEncoder

df = df.apply(LabelEncoder().fit_transform)
df
# Out:
#       Daily events  Prioritising workload  Writing notes  Workaholism  \
# 0                1                      1              4            3
# 1                2                      1              3            4
# 2                0                      1              4            2
# 4                2                      0              1            2
# 5                1                      1              2            2
# ...            ...                    ...            ...          ...
# 1005             2                      1              0            3
# 1006             0                      2              0            4
# 1007             2                      0              0            0
# 1008             2                      0              4            0
# 1009             2                      4              3            4
#
#       Thinking ahead  Final judgement  Reliability  Keeping promises  \
# ...

# %% [markdown]
# Choose the factors

# %%
# !pip install factor_analyzer
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.5/42.5 kB 1.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.7/203.7 kB 7.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.9/98.9 kB 13.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 60.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.9/468.9 kB 52.2 MB/s eta 0:00:00
# ...
#   Created wheel for factor_analyzer: filename=factor_analyzer-0.5.0-py2.py3-none-any.whl size=42487 sha256=c00bb43024628b55816d62d3e7a5bcb8d06499eaa710adc1e00d727d2259a4bb
#   Stored in directory: /root/.cache/pip/wheels/74/a2/6c/26fb1addf1ce6c60a8cef8397f2999f0a1e6e2fcddc8abf33e
# Successfully built factor_analyzer
# ...

# %%
#Try the model with all the variables
from factor_analyzer import FactorAnalyzer         # pip install factor_analyzer
fa = FactorAnalyzer(rotation="varimax")
fa.fit(df)

# Check Eigenvalues
ev, v = fa.get_eigenvalues()
ev

# Create scree plot using matplotlib
plt.scatter(range(1,df.shape[1]+1),ev)
plt.plot(range(1,df.shape[1]+1),ev)
plt.title('Scree Plot')
plt.xlabel('Factors')
plt.ylabel('Eigenvalue')
plt.grid()
plt.show()

# %%
from IPython.display import display, Image
display(Image(filename='Varimax.png'))

# %%
#Factor analysis with 5 fators
fa = FactorAnalyzer(5, rotation="varimax")
fa.fit(df)
AF = fa.loadings_
AF = pd.DataFrame(AF)
AF.index = df.columns
AF
# Out:
#                                        0         1         2         3  \
# Daily events                    0.250416  0.058953  0.206877  0.026094
# Prioritising workload          -0.012803 -0.150045  0.555946  0.078913
# Writing notes                  -0.006039 -0.015927  0.420849  0.225307
# Workaholism                     0.069524  0.029275  0.527082  0.088573
# Thinking ahead                  0.023475  0.127909  0.530457  0.035213
# Final judgement                 0.046188  0.112493  0.119861  0.381338
# Reliability                     0.061028 -0.102481  0.539373  0.073534
# Keeping promises                0.053358 -0.034661  0.420538  0.121450
# Loss of interest                0.273777  0.226286  0.003524 -0.149262
# Friends versus money            0.021279 -0.111839  0.022026  0.381357
# Funniness                       0.312861  0.131400 -0.043014 -0.018258
# Fake                            0.091188  0.469616 -0.024535 -0.191798
# ...

# %%
#Get Top variables for each Factor
F = AF.unstack()
F = pd.DataFrame(F).reset_index()
F = F.sort_values(['level_0',0], ascending=False).groupby('level_0').head(5)    # Top 5
F = F.sort_values(by="level_0")
F.columns=["FACTOR","Variable","Varianza_Explica"]
F = F.reset_index().drop(["index"],axis=1)
F
# Out:
#     FACTOR                  Variable  Varianza_Explica
# 0        0           New environment          0.470076
# 1        0             Energy levels          0.499978
# 2        0         Number of friends          0.514994
# 3        0               Socializing          0.537811
# 4        0  Knowing the right people          0.478657
# 5        1               Mood swings          0.353226
# 6        1            Self-criticism          0.398420
# 7        1                      Fake          0.469616
# 8        1         Changing the past          0.482307
# 9        1                Loneliness          0.542350
# 10       2             Writing notes          0.420849
# 11       2               Workaholism          0.527082
# 12       2            Thinking ahead          0.530457
# 13       2     Prioritising workload          0.555946
# 14       2               Reliability          0.539373
# 15       3      Friends versus money          0.381357
# ...

# %%
#Show the Top for each Factor
F = F.pivot(columns='FACTOR')["Variable"]
F.apply(lambda x: pd.Series(x.dropna().to_numpy()))
# Out:
# FACTOR                         0                  1                      2  \
# 0                New environment        Mood swings          Writing notes
# 1                  Energy levels     Self-criticism            Workaholism
# 2              Number of friends               Fake         Thinking ahead
# 3                    Socializing  Changing the past  Prioritising workload
# 4       Knowing the right people         Loneliness            Reliability
#
# FACTOR                       3                        4
# 0         Friends versus money  Appearence and gestures
# 1               Life struggles           Life struggles
# 2       Finding lost valuables              Mood swings
# 3                     Children                   Health
# 4                          God            Getting angry
